# %%
# import os
# import librosa
# import numpy as np
# import pandas as pd

# # Path to the folder containing audio files
# AUDIO_FOLDER = r"D:\projects\clg work\emotion-recognition-using-speech-master\dataset-depression\depression2"

# # Output file for saving features
# OUTPUT_FILE = "mfcc_features_depression1.csv"

# # Function to extract MFCC features
# def extract_mfcc(file_path, n_mfcc=13):
#     try:
#         # Load the audio file
#         y, sr = librosa.load(file_path, sr=None)  # sr=None preserves the native sampling rate
#         # Extract MFCC features
#         mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
#         # Return the mean of each MFCC dimension
#         return np.mean(mfcc.T, axis=0)
#     except Exception as e:
#         print(f"Error processing {file_path}: {e}")
#         return None

# # List to store the extracted features
# features_list = []

# # Iterate over all files in the folder
# for file_name in os.listdir(AUDIO_FOLDER):
#     if file_name.endswith(".wav"):  # Check if the file is a .wav file
#         file_path = os.path.join(AUDIO_FOLDER, file_name)
#         print(f"Processing file: {file_name}")
        
#         # Extract MFCC features
#         mfcc_features = extract_mfcc(file_path)
#         if mfcc_features is not None:
#             features_list.append([file_name] + list(mfcc_features))

# # Create a DataFrame for the features
# columns = ["file_name"] + [f"mfcc_{i+1}" for i in range(13)]  # File name + 13 MFCC features
# features_df = pd.DataFrame(features_list, columns=columns)


# # Save the features to a CSV file
# features_df.to_csv(OUTPUT_FILE, index=False)
# print(f"MFCC features extracted and saved to {OUTPUT_FILE}")

import os
import librosa
import numpy as np
import pandas as pd
import random  # Needed for augmentation

# Path to the folder containing audio files
AUDIO_FOLDER = r"D:\projects\clg work\emotion-recognition-using-speech-master\dataset-depression\depression2"

# Output file for saving features
OUTPUT_FILE = "mfcc_features_depression1.csv"

# -------------------- AUGMENTATION FUNCTIONS -------------------- #
def add_noise(X, noise_factor=0.05):
    noise = np.random.normal(loc=0.0, scale=noise_factor, size=X.shape)
    return X + noise

def time_stretch(X, rate=1.2):
    return librosa.effects.time_stretch(X, rate=rate)

def pitch_shift(X, sr, n_steps=2):
    return librosa.effects.pitch_shift(X, sr=sr, n_steps=n_steps)

def augment_audio(X, sr):
    augmentation_choice = random.choice(['noise', 'stretch', 'pitch', 'none'])
    
    if augmentation_choice == 'noise':
        return add_noise(X)
    elif augmentation_choice == 'stretch':
        return time_stretch(X, rate=random.uniform(0.8, 1.2))  # Random stretch rate
    elif augmentation_choice == 'pitch':
        return pitch_shift(X, sr, n_steps=random.randint(-2, 2))  # Random pitch shift
    return X  # No augmentation

# -------------------- FEATURE EXTRACTION FUNCTION -------------------- #
def extract_mfcc(file_path, n_mfcc=13, augment=False):
    try:
        # Load the audio file (native sampling rate)
        y, sr = librosa.load(file_path, sr=None)
        # Apply augmentation if requested
        if augment:
            y = augment_audio(y, sr)
        # Extract MFCC features
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        # Return the mean of each MFCC dimension
        return np.mean(mfcc.T, axis=0)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# List to store the extracted features
features_list = []

# Iterate over all files in the folder
for file_name in os.listdir(AUDIO_FOLDER):
    if file_name.endswith(".wav"):  # Process only .wav files
        file_path = os.path.join(AUDIO_FOLDER, file_name)
        print(f"Processing file: {file_name}")
        
        # Extract MFCC features from raw audio
        raw_features = extract_mfcc(file_path, n_mfcc=13, augment=False)
        if raw_features is not None:
            features_list.append([file_name, "raw"] + list(raw_features))
        
        # Extract MFCC features from augmented audio
        aug_features = extract_mfcc(file_path, n_mfcc=13, augment=True)
        if aug_features is not None:
            features_list.append([file_name, "augmented"] + list(aug_features))

# Create a DataFrame for the features
columns = ["file_name", "data_type"] + [f"mfcc_{i+1}" for i in range(13)]
features_df = pd.DataFrame(features_list, columns=columns)

# Save the features to a CSV file
features_df.to_csv(OUTPUT_FILE, index=False)
print(f"MFCC features (raw and augmented) extracted and saved to {OUTPUT_FILE}")
# Out:
# Processing file: YAF_bean_sad.wav
# Processing file: YAF_beg_sad.wav
# Processing file: YAF_bite_sad.wav
# Processing file: YAF_boat_sad.wav
# Processing file: YAF_bone_sad.wav
# Processing file: YAF_book_sad.wav
# Processing file: YAF_bought_sad.wav
# Processing file: YAF_burn_sad.wav
# Processing file: YAF_cab_sad.wav
# Processing file: YAF_calm_sad.wav
# Processing file: YAF_came_sad.wav
# Processing file: YAF_cause_sad.wav
# Processing file: YAF_chain_sad.wav
# Processing file: YAF_chair_sad.wav
# Processing file: YAF_chalk_sad.wav
# Processing file: YAF_chat_sad.wav
# Processing file: YAF_check_sad.wav
# Processing file: YAF_cheek_sad.wav
# Processing file: YAF_chief_sad.wav
# Processing file: YAF_choice_sad.wav
# Processing file: YAF_cool_sad.wav
# Processing file: YAF_dab_sad.wav
# Processing file: YAF_date_sad.wav
# Processing file: YAF_dead_sad.wav
# Processing file: YAF_death_sad.wav
# Processing file: YAF_deep_sad.wav
# Processing file: YAF_dime_sad.wav
# Processing file: YAF_dip_sad.wav
# Processing file: YAF_ditch_sad.wav
# Processing file: YAF_dodge_sad.wav
# Processing file: YAF_dog_sad.wav
# Processing file: YAF_doll_sad.wav
# Processing file: YAF_door_sad.wav
# Processing file: YAF_fail_sad.wav
# Processing file: YAF_fall_sad.wav
# Processing file: YAF_far_sad.wav
# Processing file: YAF_fat_sad.wav
# Processing file: YAF_fit_sad.wav
# Processing file: YAF_five_sad.wav
# Processing file: YAF_food_sad.wav
# Processing file: YAF_gap_sad.wav
# Processing file: YAF_gas_sad.wav
# Processing file: YAF_gaze_sad.wav
# Processing file: YAF_germ_sad.wav
# Processing file: YAF_get_sad.wav
# Processing file: YAF_gin_sad.wav
# Processing file: YAF_goal_sad.wav
# Processing file: YAF_good_sad.wav
# Processing file: YAF_goose_sad.wav
# Processing file: YAF_gun_sad.wav
# Processing file: YAF_half_sad.wav
# Processing file: YAF_hall_sad.wav
# Processing file: YAF_hash_sad.wav
# Processing file: YAF_hate_sad.wav
# Processing file: YAF_have_sad.wav
# Processing file: YAF_haze_sad.wav
# Processing file: YAF_hire_sad.wav
# Processing file: YAF_hit_sad.wav
# Processing file: YAF_hole_sad.wav
# Processing file: YAF_home_sad.wav
# Processing file: YAF_hurl_sad.wav
# Processing file: YAF_hush_sad.wav
# Processing file: YAF_jail_sad.wav
# Processing file: YAF_jar_sad.wav
# Processing file: YAF_join_sad.wav
# Processing file: YAF_judge_sad.wav
# Processing file: YAF_jug_sad.wav
# Processing file: YAF_juice_sad.wav
# Processing file: YAF_keen_sad.wav
# Processing file: YAF_keep_sad.wav
# Processing file: YAF_keg_sad.wav
# Processing file: YAF_kick_sad.wav
# Processing file: YAF_kill_sad.wav
# Processing file: YAF_king_sad.wav
# Processing file: YAF_kite_sad.wav
# Processing file: YAF_knock_sad.wav
# Processing file: YAF_late_sad.wav
# Processing file: YAF_laud_sad.wav
# Processing file: YAF_lean_sad.wav
# Processing file: YAF_learn_sad.wav
# Processing file: YAF_lease_sad.wav
# Processing file: YAF_lid_sad.wav
# Processing file: YAF_life_sad.wav
# Processing file: YAF_limb_sad.wav
# Processing file: YAF_live_sad.wav
# Processing file: YAF_loaf_sad.wav
# Processing file: YAF_long_sad.wav
# Processing file: YAF_lore_sad.wav
# Processing file: YAF_lose_sad.wav
# Processing file: YAF_lot_sad.wav
# Processing file: YAF_love_sad.wav
# Processing file: YAF_luck_sad.wav
# Processing file: YAF_make_sad.wav
# Processing file: YAF_match_sad.wav
# Processing file: YAF_merge_sad.wav
# Processing file: YAF_mess_sad.wav
# Processing file: YAF_met_sad.wav
# Processing file: YAF_mill_sad.wav
# Processing file: YAF_mob_sad.wav
# Processing file: YAF_mode_sad.wav
# Processing file: YAF_mood_sad.wav
# Processing file: YAF_moon_sad.wav
# Processing file: YAF_mop_sad.wav
# Processing file: YAF_mouse_sad.wav
# Processing file: YAF_nag_sad.wav
# Processing file: YAF_name_sad.wav
# Processing file: YAF_near_sad.wav
# Processing file: YAF_neat_sad.wav
# Processing file: YAF_nice_sad.wav
# Processing file: YAF_note_sad.wav
# Processing file: YAF_numb_sad.wav
# Processing file: YAF_pad_sad.wav
# Processing file: YAF_page_sad.wav
# Processing file: YAF_pain_sad.wav
# Processing file: YAF_pass_sad.wav
# Processing file: YAF_pearl_sad.wav
# Processing file: YAF_peg_sad.wav
# Processing file: YAF_perch_sad.wav
# Processing file: YAF_phone_sad.wav
# Processing file: YAF_pick_sad.wav
# Processing file: YAF_pike_sad.wav
# Processing file: YAF_pole_sad.wav
# Processing file: YAF_pool_sad.wav
# Processing file: YAF_puff_sad.wav
# Processing file: YAF_rag_sad.wav
# Processing file: YAF_raid_sad.wav
# Processing file: YAF_rain_sad.wav
# Processing file: YAF_raise_sad.wav
# Processing file: YAF_rat_sad.wav
# Processing file: YAF_reach_sad.wav
# Processing file: YAF_read_sad.wav
# Processing file: YAF_red_sad.wav
# Processing file: YAF_ring_sad.wav
# Processing file: YAF_ripe_sad.wav
# Processing file: YAF_road_sad.wav
# Processing file: YAF_room_sad.wav
# Processing file: YAF_rose_sad.wav
# Processing file: YAF_rot_sad.wav
# Processing file: YAF_rough_sad.wav
# Processing file: YAF_rush_sad.wav
# Processing file: YAF_said_sad.wav
# Processing file: YAF_sail_sad.wav
# Processing file: YAF_search_sad.wav
# Processing file: YAF_seize_sad.wav
# Processing file: YAF_sell_sad.wav
# Processing file: YAF_shack_sad.wav
# Processing file: YAF_shall_sad.wav
# Processing file: YAF_shawl_sad.wav
# Processing file: YAF_sheep_sad.wav
# Processing file: YAF_shirt_sad.wav
# Processing file: YAF_should_sad.wav
# Processing file: YAF_shout_sad.wav
# Processing file: YAF_size_sad.wav
# Processing file: YAF_soap_sad.wav
# Processing file: YAF_soup_sad.wav
# Processing file: YAF_sour_sad.wav
# Processing file: YAF_south_sad.wav
# Processing file: YAF_sub_sad.wav
# Processing file: YAF_such_sad.wav
# Processing file: YAF_sure_sad.wav
# Processing file: YAF_take_sad.wav
# Processing file: YAF_talk_sad.wav
# Processing file: YAF_tape_sad.wav
# Processing file: YAF_team_sad.wav
# Processing file: YAF_tell_sad.wav
# Processing file: YAF_thin_sad.wav
# Processing file: YAF_third_sad.wav
# Processing file: YAF_thought_sad.wav
# Processing file: YAF_thumb_sad.wav
# Processing file: YAF_time_sad.wav
# Processing file: YAF_tip_sad.wav
# Processing file: YAF_tire_sad.wav
# Processing file: YAF_ton_sad.wav
# Processing file: YAF_tool_sad.wav
# Processing file: YAF_tough_sad.wav
# Processing file: YAF_turn_sad.wav
# Processing file: YAF_vine_sad.wav
# Processing file: YAF_voice_sad.wav
# Processing file: YAF_void_sad.wav
# Processing file: YAF_vote_sad.wav
# Processing file: YAF_wag_sad.wav
# Processing file: YAF_walk_sad.wav
# Processing file: YAF_wash_sad.wav
# Processing file: YAF_week_sad.wav
# Processing file: YAF_wheat_sad.wav
# Processing file: YAF_when_sad.wav
# Processing file: YAF_which_sad.wav
# Processing file: YAF_whip_sad.wav
# Processing file: YAF_white_sad.wav
# Processing file: YAF_wife_sad.wav
# Processing file: YAF_wire_sad.wav
# Processing file: YAF_witch_sad.wav
# Processing file: YAF_yearn_sad.wav
# Processing file: YAF_yes_sad.wav
# Processing file: YAF_young_sad.wav
# Processing file: YAF_youth_sad.wav
# MFCC features (raw and augmented) extracted and saved to mfcc_features_depression1.csv
